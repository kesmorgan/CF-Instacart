# %% [markdown]
# # Contents List
# - Importing Libraries and Data Frames
#     - orders_products_flags
#     - customers
# - Wrangle and Check customers DF
# - Combine data
# - Export
#     - orders_products_customers

# %% [markdown]
# # 01. Import Libraries and Dataframes

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\kesmc\Documents\2023 Instacart Basket Analysis CF'

# %%
ords_prods_merge=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_flags.pkl'))

# %%
customers=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %%
customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...  prices    price_range_loc    busiest_days  \
# ...

# %% [markdown]
# # 02. Wrangle and Check Customers DF

# %%
#rename surname columnm
customers.rename(columns={'Surnam':'Last Name'}, inplace=True)

# %%
#rename columnm
customers.rename(columns={'STATE':'State'}, inplace=True)

# %%
customers.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %% [markdown]
# Keeping all columns as they all seem relevant for Analysis

# %%
customers.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# ### quality and consistencey checks

# %%
# Check for Missing Values
customers.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Last Name           0
# Gender              0
# State               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
df_nan=customers[customers['First Name'].isnull()==True]

# %%
df_nan.head(20)
# Out:
#      user_id First Name   Last Name  Gender           State  Age date_joined  \
# 53     76659        NaN     Gilbert    Male        Colorado   26    1/1/2017
# 73     13738        NaN       Frost  Female       Louisiana   39    1/1/2017
# 82     89996        NaN      Dawson  Female          Oregon   52    1/1/2017
# 99     96166        NaN     Oconnor    Male        Oklahoma   51    1/1/2017
# 105    29778        NaN      Dawson  Female            Utah   63    1/1/2017
# 128     8562        NaN     Oconnor    Male            Utah   46    1/1/2017
# 140   149267        NaN  Hutchinson    Male  South Carolina   20    1/1/2017
# 149    82632        NaN         Orr    Male          Hawaii   61    1/1/2017
# 155   172331        NaN  Williamson  Female          Alaska   27    1/1/2017
# 236   182963        NaN   Nicholson  Female      New Mexico   58    1/2/2017
# 241    49727        NaN       Moran    Male          Alaska   53    1/2/2017
# ...

# %% [markdown]
# Seems ok to leave as is, column is not pertinent so if causes issues for data analysis column can be dropped to keep all rows.

# %%
# Check for duplicates
df_dups=customers[customers.duplicated()]

# %%
df_dups.head(20)
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Last Name, Gender, State, Age, date_joined, n_dependants, fam_status, income]
# Index: []

# %% [markdown]
# No duplicates

# %%
#Check data types
for col in customers.columns.tolist():
  weird = (customers[[col]].applymap(type) != customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (customers[weird]) > 0:
    print (col)
# Out:
# First Name

# %% [markdown]
# First Name mixed because of missing names - do not want to change if info is used beyond analysis scope. As mentioned ablove if issue, can delete column.

# %% [markdown]
# # Export to break steps

# %%
customers.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'customers2.pkl'))

# %%
#Import in steps
customers=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'customers2.pkl'))

# %% [markdown]
# # 03. Combine data

# %%
customers['user_id'].dtype
# Out:
# dtype('int64')

# %%
ords_prods_merge['user_id'].dtype
# Out:
# dtype('int64')

# %%
customers.shape
# Out:
# (206209, 10)

# %%
ords_prods_merge.shape
# Out:
# (32404859, 24)

# %%
ords_prods_customers=ords_prods_merge.join(customers.set_index('user_id'), on = 'user_id', how='inner', lsuffix="_x", rsuffix="_y")

# %%
ords_prods_customers.head(50)
# Out:
#         Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0                  0   2539329        1             1                   2
# 1                  1   2398795        1             2                   3
# 2                  2    473747        1             3                   3
# 3                  3   2254736        1             4                   4
# 4                  4    431534        1             5                   4
# 5                  5   3367565        1             6                   2
# 6                  6    550135        1             7                   1
# 7                  7   3108588        1             8                   1
# 8                  8   2295261        1             9                   1
# 9                  9   2550362        1            10                   4
# 35791              0   2539329        1             1                   2
# 51726              0   2539329        1             1                   2
# ...

# %%
ords_prods_customers.shape
# Out:
# (32404859, 33)

# %%
ords_prods_customers.tail()
# Out:
#           Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 32311521       1768145    156685   106143            26                   4
# 32393481       1101646    484769    66343             1                   6
# 32393482       1101647   1561557    66343             2                   1
# 32393483       1101648    276317    66343             3                   6
# 32393484       1101649   2922475    66343             4                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 32311521                 23                     5.0       19675
# 32393481                 11                     NaN       47210
# 32393482                 11                    30.0       47210
# 32393483                 15                    19.0       47210
# 32393484                 12                    30.0       47210
#
#           add_to_cart_order  reordered  ...         frequency_flag  \
# ...

# %% [markdown]
# # 04. Export

# %%
ords_prods_customers.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_customers.pkl'))
